# %% [markdown]
# ## How to do curve fitting and plotting with Jupyter Notebooks
#
# This is the example notebook. Refer to 'Step 4: Data Analysis' of 'mse201_Dft_f22_instructions.pdf', it will walk you through the notebook.
# This will also help you to complete 'datafittig_for_assignment' notebook where you will obtain the plots and fits for the assignment.

# %%
import numpy as np
from numpy.polynomial.polynomial import polyfit,polyval
import matplotlib.pyplot as plt

# %%
x = np.loadtxt('x.txt')
y_line = np.loadtxt('y_line.txt')

plt.plot(x, y_line, 'bo')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
p_line = polyfit(x, y_line, deg=1)
print(p_line)
# Out:
# [8.22017836 4.86500971]

# %%
y_line_hat = polyval(x, p_line)
plt.plot(x, y_line, 'bo', label='data points')
plt.plot(x, y_line_hat, 'k-', label='fitted curve')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
y_quad = np.loadtxt('y_quad.txt')
p_quad = polyfit(x, y_quad, deg=2)
print(p_quad)
# Out:
# [3.12600872 2.3999193  1.00969289]

# %%
y_quad_hat = polyval(x, p_quad)
plt.plot(x, y_quad, 'bo', label='data points')
plt.plot(x, y_quad_hat, 'k-', label='fitted curve')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
from scipy.optimize import curve_fit

# %%
y_exp = np.loadtxt('y_exp.txt')

def Exp(x, A, B, C):
    return A*np.exp(B*x) + C

popt, pcov = curve_fit(Exp, x, y_exp)
print(popt)
print(pcov)
# Out:
# [-1.43763278e+06  7.51200318e-06  1.43768398e+06]
# [[ 3.41317516e+17  1.78441045e+06 -3.41317516e+17]
#  [ 1.78441047e+06  9.32891130e-06 -1.78441047e+06]
#  [-3.41317516e+17 -1.78441045e+06  3.41317516e+17]]

# %%
y_exp_hat = Exp(x, popt[0], popt[1], popt[2])
plt.plot(x, y_exp, 'bo', label='data points')
plt.plot(x, y_exp_hat, 'k-', label='fitted curve')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
popt, pcov = curve_fit(Exp, x, y_exp, p0=[1.0, -1.0, 1.0])
print(popt)
print(pcov)
# Out:
# [ 2.81738694 -0.50423345  6.14997679]
# [[ 3.55225880e-01  1.33472529e-02 -7.99304022e-01]
#  [ 1.33472529e-02  5.06799613e-04 -2.80990944e-02]
#  [-7.99304022e-01 -2.80990944e-02  6.38058862e+00]]

# %%
y_exp_hat = Exp(x, popt[0], popt[1], popt[2])
plt.plot(x, y_exp, 'bo', label='data points')
plt.plot(x, y_exp_hat, 'k-', label='fitted curve')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
